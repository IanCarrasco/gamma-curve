# %%
# !pip install -U -q ipywidgets
# !pip install -U -q matplotlib 
# !pip install -U -q pandas 
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# WARNING: You are using pip version 19.1.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# WARNING: You are using pip version 19.1.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# WARNING: You are using pip version 19.1.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact, interact_manual, FloatSlider, IntRangeSlider, Text
import matplotlib.pyplot as plt
import pandas as pd

# %%
CONST = 3.009 
x = list(range(0,256))
y = [(j ** 2.2)/CONST for j in x]
df=None

# %%
def generate_graph(gamma=2.2, value_range=[0,10], edit=False):
    if edit:
        for i in range(value_range[0],value_range[1]):
            y[i] = (i ** gamma)/CONST
    
    for xc in value_range:
        plt.axvline(x=xc, color='k', linestyle='--')
    plt.plot(x, y)

interact(generate_graph, gamma=FloatSlider(value=2.2, min=1, max=2.5, step=0.01, continuous_update=False),
                         value_range=IntRangeSlider(value=[0,255],min=0, max=255, continuous_update=False))
# Out:
# interactive(children=(FloatSlider(value=2.2, continuous_update=False, description='gamma', max=2.5, min=1.0, s…
# <function __main__.generate_graph>

# %% [markdown]
# # View Table

# %%
def show_table():
    pd.options.display.max_rows = 999
    df = pd.DataFrame(list(zip(x,y)), columns=['Step', 'Value'])
    return df

values = show_table()
values
# Out:
#      Step         Value
# 0       0      0.000000
# 1       1      0.332336
# 2       2      1.527017
# 3       3      3.726015
# 4       4      7.016327
# 5       5     11.463357
# 6       6     17.120268
# 7       7     24.032198
# 8       8     32.238571
# 9       9     41.774507
# 10     10     52.671758
# 11     11     64.959357
# 12     12     78.664096
# 13     13     93.810875
# 14     14    110.422987
# 15     15    128.522328
# 16     16    148.129574
# 17     17    169.264327
# 18     18    191.945230
# 19     19    216.190066
# 20     20    242.015846
# 21     21    269.438878
# 22     22    298.474828
# 23     23    329.138777
# 24     24    361.445269
# 25     25    395.408346
# 26     26    431.041592
# 27     27    468.358162
# 28     28    507.370814
# 29     29    548.091930
# 30     30    590.533545
# 31     31    634.707366
# 32     32    680.624792
# 33     33    728.296931
# 34     34    777.734617
# 35     35    828.948423
# 36     36    881.948679
# ...

# %% [markdown]
# # Export Values

# %%
@interact_manual
def export_df(filename=""):
    values.to_csv('{}.csv'.format(filename), index=False)
    print('Exported.')
# Out:
# interactive(children=(Text(value='', description='filename'), Button(description='Run Interact', style=ButtonS…
